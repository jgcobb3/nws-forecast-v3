# %%
from nws_forecast_v3 import GridPoint

# %%
pt = GridPoint(35.75, -78.70)
df = pt.to_dataframe()

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

df['heatIndex'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from cattle_heat_stress import CattleHeatStress

chs = CattleHeatStress(35.75, -78.70).forecast()
chs.plot()
